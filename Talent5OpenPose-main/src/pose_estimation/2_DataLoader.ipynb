# %% [markdown]
# # 4.2 DataLoader

# %% [markdown]
# # Mục tiêu bài học
#
# 1.	Hiểu về mask data
# 2.	Tạo được class về OpenPose
# 3.	Hiểu về tiền xử lý OpenPose và Data Augmentation

# %% [markdown]
# # Chuẩn bị

# %%
import json
import os
import os.path as osp
import numpy as np
import cv2
from PIL import Image
from matplotlib import cm
import matplotlib.pyplot as plt
# %matplotlib inline

import torch.utils.data as data

# %%
def make_datapath_list(rootpath):
    # read json
    json_path = osp.join(rootpath, 'COCO.json')
    with open(json_path) as data_file:
        data_this = json.load(data_file)
        data_json = data_this['root']

    # create index
    num_samples = len(data_json)
    train_indexes = []
    val_indexes = []
    for count in range(num_samples):
        if data_json[count]['isValidation'] != 0.:
            val_indexes.append(count)
        else:
            train_indexes.append(count)

    # make image paths
    train_img_list = list()
    val_img_list = list()

    for idx in train_indexes:
        img_path = os.path.join(rootpath, data_json[idx]['img_paths'])
        train_img_list.append(img_path)

    for idx in val_indexes:
        img_path = os.path.join(rootpath, data_json[idx]['img_paths'])
        val_img_list.append(img_path)

    # create masks
    train_mask_list = []
    val_mask_list = []

    for idx in train_indexes:
        img_idx = data_json[idx]['img_paths'][-16:-4]
        anno_path = "./data/mask/train2014/mask_COCO_tarin2014_" + img_idx+'.jpg'
        train_mask_list.append(anno_path)

    for idx in val_indexes:
        img_idx = data_json[idx]['img_paths'][-16:-4]
        anno_path = "./data/mask/val2014/mask_COCO_val2014_" + img_idx+'.jpg'
        val_mask_list.append(anno_path)

    # create anotation
    train_meta_list = list()
    val_meta_list = list()

    for idx in train_indexes:
        train_meta_list.append(data_json[idx])

    for idx in val_indexes:
        val_meta_list.append(data_json[idx])

    return train_img_list, train_mask_list, val_img_list, val_mask_list, train_meta_list, val_meta_list

# %%
# Test
train_img_list, train_mask_list, val_img_list, val_mask_list, train_meta_list, val_meta_list = make_datapath_list(
    rootpath="./data/")

val_meta_list[24]
# Out:
# {'dataset': 'COCO_val',
#  'isValidation': 1.0,
#  'img_paths': 'val2014/COCO_val2014_000000000488.jpg',
#  'img_width': 640.0,
#  'img_height': 406.0,
#  'objpos': [233.075, 275.815],
#  'image_id': 488.0,
#  'bbox': [180.76, 210.3, 104.63, 131.03],
#  'segment_area': 4851.846,
#  'num_keypoints': 15.0,
#  'joint_self': [[266.0, 231.0, 1.0],
#   [0.0, 0.0, 2.0],
#   [264.0, 229.0, 1.0],
#   [0.0, 0.0, 2.0],
#   [256.0, 231.0, 1.0],
#   [261.0, 239.0, 1.0],
#   [238.0, 239.0, 1.0],
#   [267.0, 259.0, 1.0],
#   [222.0, 262.0, 1.0],
#   [272.0, 267.0, 1.0],
#   [243.0, 256.0, 1.0],
#   [244.0, 278.0, 1.0],
#   [229.0, 279.0, 1.0],
#   [269.0, 297.0, 1.0],
#   [219.0, 310.0, 1.0],
#   [267.0, 328.0, 1.0],
#   [192.0, 329.0, 1.0]],
#  'scale_provided': 0.356,
#  'joint_others': [[[0.0, 0.0, 2.0],
#    [0.0, 0.0, 2.0],
#    [0.0, 0.0, 2.0],
#    [0.0, 0.0, 2.0],
#    [174.0, 261.0, 1.0],
#    [169.0, 275.0, 1.0],
#    [155.0, 275.0, 1.0],
#    [190.0, 282.0, 1.0],
#    [142.0, 299.0, 1.0],
#    [217.0, 285.0, 1.0],
#    [133.0, 329.0, 1.0],
#    [0.0, 0.0, 2.0],
#    [127.0, 311.0, 1.0],
#    [170.0, 307.0, 1.0],
#    [180.0, 310.0, 1.0],
#    [140.0, 341.0, 1.0],
#    [148.0, 346.0, 1.0]],
#   [[0.0, 0.0, 2.0],
#    [0.0, 0.0, 2.0],
#    [0.0, 0.0, 2.0],
#    [0.0, 0.0, 2.0],
#    [106.0, 227.0, 1.0],
#    [92.0, 232.0, 1.0],
#    [101.0, 232.0, 1.0],
#    [0.0, 0.0, 2.0],
#    [97.0, 257.0, 1.0],
#    [0.0, 0.0, 2.0],
#    [94.0, 282.0, 1.0],
#    [55.0, 270.0, 1.0],
#    [65.0, 271.0, 1.0],
#    [60.0, 302.0, 1.0],
#    [99.0, 303.0, 1.0],
#    [45.0, 343.0, 1.0],
#    [102.0, 346.0, 1.0]]],
#  'annolist_index': 18.0,
#  'people_index': 1.0,
#  'numOtherPeople': 2.0,
#  'scale_provided_other': [0.301, 0.414],
#  'objpos_other': [[175.74, 300.7], [80.29, 284.2]],
#  'bbox_other': [[112.24, 245.32, 127.0, 110.76],
#   [34.67, 208.02, 91.24, 152.36]],
#  'segment_area_other': [5682.173, 7186.222],
#  'num_keypoints_other': [12.0, 11.0]}

# %% [markdown]
# # Check mask

# %%
index = 24
print(len(val_img_list))

# ReadImage
img = cv2.imread(val_img_list[index])
print(val_img_list[index])
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# Mask
mask_miss = cv2.imread(val_mask_list[index])
print(mask_miss)
mask_miss = cv2.cvtColor(mask_miss, cv2.COLOR_BGR2RGB)
plt.imshow(mask_miss)
plt.show()

# hợp file
blend_img = cv2.addWeighted(img, 0.4, mask_miss, 0.6, 0)
plt.imshow(blend_img)
plt.show()
# Out:
# 4873
# ./data/val2014/COCO_val2014_000000000488.jpg
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %% [markdown]
# # Preprosessing

# %%
from utils.data_augumentation import Compose, get_anno, add_neck, aug_scale, aug_rotate, aug_croppad, aug_flip, remove_illegal_joint, Normalize_Tensor, no_Normalize_Tensor


class DataTransform():
    def __init__(self):

        self.data_transform = {
            'train': Compose([
                get_anno(), 
                add_neck(), 
                aug_scale(),
                aug_rotate(),
                aug_croppad(),
                aug_flip(),
                remove_illegal_joint(),
                no_Normalize_Tensor()
            ]),
            'val': Compose([
                
            ])
        }

    def __call__(self, phase, meta_data, img, mask_miss):
        meta_data, img, mask_miss = self.data_transform[phase](
            meta_data, img, mask_miss)

        return meta_data, img, mask_miss

# %%
index = 24
img = cv2.imread(val_img_list[index])
mask_miss = cv2.imread(val_mask_list[index])
meat_data = val_meta_list[index]

# Preprocessing
transform = DataTransform()
meta_data, img, mask_miss = transform("train", meat_data, img, mask_miss)

# Display
img = img.numpy().transpose((1, 2, 0))
plt.imshow(img)
plt.show()

# Display Mask
mask_miss = mask_miss.numpy().transpose((1, 2, 0))
plt.imshow(mask_miss)
plt.show()

img = Image.fromarray(np.uint8(img*255))
img = np.asarray(img.convert('RGB'))
mask_miss = Image.fromarray(np.uint8((mask_miss)))
mask_miss = np.asarray(mask_miss.convert('RGB'))
blend_img = cv2.addWeighted(img, 0.4, mask_miss, 0.6, 0)
plt.imshow(blend_img)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from utils.dataloader import get_ground_truth

# Read Image
index = 24
img = cv2.imread(val_img_list[index])
mask_miss = cv2.imread(val_mask_list[index])
meat_data = val_meta_list[index]

# Preprocessing
meta_data, img, mask_miss = transform("train", meat_data, img, mask_miss)

img = img.numpy().transpose((1, 2, 0))
mask_miss = mask_miss.numpy().transpose((1, 2, 0))

# Anotation
print("metadata = {}".format(meta_data))
heat_mask, heatmaps, paf_mask, pafs = get_ground_truth(meta_data, mask_miss)

plt.imshow(img)
plt.show()
# Out:
# metadata = {'dataset': 'COCO_val', 'img_height': 406, 'img_width': 640, 'isValidation': 1.0, 'people_index': 1, 'annolist_index': 18, 'objpos': array([149.94511605, 189.40430424]), 'scale_provided': 0.356, 'joint_self': array([[201.86021575, 163.57760748,   1.        ],
#        [183.20908539, 163.3558167 ,   1.        ],
#        [172.0849444 , 157.62740312,   1.        ],
#        [146.27329706, 171.31078857,   1.        ],
#        [168.60475057, 175.77344184,   1.        ],
#        [193.40621462, 168.60686248,   1.        ],
#        [189.42092915, 190.01130424,   1.        ],
#        [190.23704551, 199.81423722,   1.        ],
#        [144.64712673, 190.41156289,   1.        ],
#        [120.5786075 , 214.37524912,   1.        ],
#        [ 86.47930212, 219.09954179,   1.        ],
#        [159.02967076, 196.64506811,   1.        ],
#        [173.13497632, 226.19248629,   1.        ],
#        [156.48255108, 253.97511491,   1.        ],
#        [200.96092785, 160.76884838,   1.        ],
#        [  1.        ,   1.        ,   2.        ],
#        [192.59009826, 158.8039295 ,   1.        ],
#        [  1.        ,   1.        ,   2.        ]]), 'numOtherPeople': 2, 'num_keypoints_other': array([12., 11.]), 'joint_others': array([[[  1.        ,   1.        ,   2.        ],
#         [ 84.44681076, 154.71987341,   1.        ],
#         [ 77.95772851, 151.37829883,   1.        ],
#         [ 54.44974862, 167.42079942,   1.        ],
#         [ 31.78560894, 190.9348417 ,   1.        ],
#         [ 90.935893  , 158.061448  ,   1.        ],
#         [107.06156513, 174.575254  ,   1.        ],
#         [130.65877896, 190.2452198 ,   1.        ],
#         [ 34.81615881, 171.38442343,   1.        ],
#         [ 84.4251493 , 195.75790499,   1.        ],
#         [ 37.5755326 , 213.8545584 ,   1.        ],
#         [  1.        ,   1.        ,   2.        ],
#         [ 76.5871352 , 188.20319176,   1.        ],
#         [ 32.5462776 , 205.40055727,   1.        ],
#         [  1.        ,   1.        ,   2.        ],
#         [  1.        ,   1.        ,   2.        ],
#         [102.25410092, 147.47012251,   1.        ],
#         [  1.        ,   1.        ,   2.        ]],
#
#        [[  1.        ,   1.        ,   2.        ],
#         [ 43.79085066,  83.35209353,   1.        ],
#         [ 48.4259094 ,  85.73893252,   1.        ],
#         [ 32.78366745, 107.00475505,   1.        ],
#         [ 18.06843725, 128.74794538,   1.        ],
#         [ 40.08280366,  81.44262234,   1.        ],
#         [  1.        ,   1.        ,   2.        ],
#         [  1.        ,   1.        ,   2.        ],
#         [  1.        ,   1.        ,   2.        ],
#         [ 12.67877223, 150.60203109,   1.        ],
#         [  1.        ,   1.        ,   2.        ],
#         [  1.        ,   1.        ,   2.        ],
#         [  1.        ,   1.        ,   2.        ],
#         [  1.        ,   1.        ,   2.        ],
#         [  1.        ,   1.        ,   2.        ],
#         [  1.        ,   1.        ,   2.        ],
#         [ 55.44780714,  83.49071277,   1.        ],
#         [  1.        ,   1.        ,   2.        ]]]), 'objpos_other': array([[ 84.91559977, 185.1031089 ],
#        [  4.30889702, 124.24265871]]), 'scale_provided_other': [0.301, 0.414], 'bbox_other': [[112.24, 245.32, 127.0, 110.76], [34.67, 208.02, 91.24, 152.36]], 'segment_area_other': [5682.173, 7186.222]}

# %%
# Headmap

# Original image
img = Image.fromarray(np.uint8(img*255))
img = np.asarray(img.convert('RGB'))

# khửu tay
heat_map = heatmaps[:, :, 6]  # 6は左肘
heat_map = Image.fromarray(np.uint8(cm.jet(heat_map)*255))
heat_map = np.asarray(heat_map.convert('RGB'))
heat_map = cv2.resize(
    heat_map, (img.shape[1], img.shape[0]), interpolation=cv2.INTER_CUBIC)

# Display Image
blend_img = cv2.addWeighted(img, 0.5, heat_map, 0.5, 0)
plt.imshow(blend_img)
plt.show()

# %%
# cổ tay
heat_map = heatmaps[:, :, 7] 
heat_map = Image.fromarray(np.uint8(cm.jet(heat_map)*255))
heat_map = np.asarray(heat_map.convert('RGB'))
heat_map = cv2.resize(
    heat_map, (img.shape[1], img.shape[0]), interpolation=cv2.INTER_CUBIC)

# Display
blend_img = cv2.addWeighted(img, 0.5, heat_map, 0.5, 0)
plt.imshow(blend_img)
plt.show()

# %%
paf = pafs[:, :, 24]

paf = Image.fromarray(np.uint8((paf)*255))
paf = np.asarray(paf.convert('RGB'))
paf = cv2.resize(
    paf, (img.shape[1], img.shape[0]), interpolation=cv2.INTER_CUBIC)

blend_img = cv2.addWeighted(img, 0.3, paf, 0.7, 0)
plt.imshow(blend_img)
plt.show()

# %%
# PAF
paf = pafs[:, :, 24] 
paf = Image.fromarray(np.uint8((paf)*255))
paf = np.asarray(paf.convert('RGB'))
paf = cv2.resize(
    paf, (img.shape[1], img.shape[0]), interpolation=cv2.INTER_CUBIC)
plt.imshow(paf)

# %% [markdown]
# # Dataset

# %%
from utils.dataloader import get_ground_truth


class COCOkeypointsDataset(data.Dataset):

    def __init__(self, img_list, mask_list, meta_list, phase, transform):
        self.img_list = img_list
        self.mask_list = mask_list
        self.meta_list = meta_list
        self.phase = phase
        self.transform = transform

    def __len__(self):
        return len(self.img_list)

    def __getitem__(self, index):
        img, heatmaps, heat_mask, pafs, paf_mask = self.pull_item(index)
        return img, heatmaps, heat_mask, pafs, paf_mask

    def pull_item(self, index):

        # 1. Read Image
        image_file_path = self.img_list[index]
        img = cv2.imread(image_file_path)  # [高さ][幅][色BGR]

        # 2. Read mask and anotation
        mask_miss = cv2.imread(self.mask_list[index])
        meat_data = self.meta_list[index]

        # 3. preprocessing
        meta_data, img, mask_miss = self.transform(
            self.phase, meat_data, img, mask_miss)

        # 4. get anotation
        mask_miss_numpy = mask_miss.numpy().transpose((1, 2, 0))
        heat_mask, heatmaps, paf_mask, pafs = get_ground_truth(
            meta_data, mask_miss_numpy)

        # 5. 
        heat_mask = heat_mask[:, :, :, 0]
        paf_mask = paf_mask[:, :, :, 0]

        # 6. 
        paf_mask = paf_mask.permute(2, 0, 1)
        heat_mask = heat_mask.permute(2, 0, 1)
        pafs = pafs.permute(2, 0, 1)
        heatmaps = heatmaps.permute(2, 0, 1)

        return img, heatmaps, heat_mask, pafs, paf_mask

# %%
# Test
train_dataset = COCOkeypointsDataset(
    val_img_list, val_mask_list, val_meta_list, phase="train", transform=DataTransform())
val_dataset = COCOkeypointsDataset(
    val_img_list, val_mask_list, val_meta_list, phase="val", transform=DataTransform())


item = train_dataset.__getitem__(0)
print(item[0].shape)  # img
print(item[1].shape)  # heatmaps,
print(item[2].shape)  # heat_mask
print(item[3].shape)  # pafs 
print(item[4].shape)  # paf_mask
# Out:
# torch.Size([3, 368, 368])
# torch.Size([19, 46, 46])
# torch.Size([19, 46, 46])
# torch.Size([38, 46, 46])
# torch.Size([38, 46, 46])

# %% [markdown]
# # DataLoader

# %%
batch_size = 8

train_dataloader = data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True)

val_dataloader = data.DataLoader(
    val_dataset, batch_size=batch_size, shuffle=False)


dataloaders_dict = {"train": train_dataloader, "val": val_dataloader}

# Test
batch_iterator = iter(dataloaders_dict["train"]) 
item = next(batch_iterator)  
print(item[0].shape)  # img
print(item[1].shape)  # heatmaps,
print(item[2].shape)  # heat_mask
print(item[3].shape)  # pafs 
print(item[4].shape)  # paf_mask
# Out:
# torch.Size([8, 3, 368, 368])
# torch.Size([8, 19, 46, 46])
# torch.Size([8, 19, 46, 46])
# torch.Size([8, 38, 46, 46])
# torch.Size([8, 38, 46, 46])
